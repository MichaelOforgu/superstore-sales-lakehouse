-- %%
-- ---------------------------------------------------------
-- Initialize lakehouse structure for Sales domain
-- ---------------------------------------------------------

-- Create catalog
CREATE CATALOG IF NOT EXISTS dev
COMMENT 'Superstore Sales data lakehouse';

-- Create schemas
CREATE SCHEMA IF NOT EXISTS dev.bronze;
CREATE SCHEMA IF NOT EXISTS dev.silver;
CREATE SCHEMA IF NOT EXISTS dev.gold;
CREATE SCHEMA IF NOT EXISTS dev.metadata;

-- Create Volume (for raw ingestion)
CREATE EXTERNAL VOLUME IF NOT EXISTS dev.bronze.bronze_volume
LOCATION 'abfss://bronze@stsuperstoredevnech.dfs.core.windows.net/';
