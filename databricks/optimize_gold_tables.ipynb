# %%
# %run ./config

# %%
# Optimize for query performance
spark.sql(f"""
OPTIMIZE {gold_catalog}.fact_orders
ZORDER BY (order_date)
""")

spark.sql(f"""
OPTIMIZE {gold_catalog}.fact_order_details
ZORDER BY (item_key)
""")
