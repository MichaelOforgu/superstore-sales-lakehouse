# %%
# Environment configuration
dbutils.widgets.text("env", "dev")

env = dbutils.widgets.get("env")

bronze_catalog = f"{env}.bronze"
silver_catalog = f"{env}.silver"
gold_catalog   = f"{env}.gold"
