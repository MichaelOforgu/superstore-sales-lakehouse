# %%
# %run ../config

# %%
spark.sql(f"""
CREATE TABLE IF NOT EXISTS {gold_catalog}.dim_customers AS
SELECT
    ROW_NUMBER() OVER (ORDER BY customer_id) AS customer_key,
    customer_id,
    email,
    full_name,
    gender,
    birth_date,
    region,
    city,
    town,
    effective_start_date,
    effective_end_date,
    is_current
FROM {silver_catalog}.customers_clean
""")
