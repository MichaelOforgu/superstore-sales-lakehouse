# %%
# %run ../config

# %%
spark.sql(f"""
CREATE TABLE IF NOT EXISTS {gold_catalog}.dim_categories AS
SELECT
    ROW_NUMBER() OVER (ORDER BY item_id) AS item_key,
    item_id,
    category1,
    category1_id,
    category2,
    category2_id,
    category3,
    category3_id,
    category4,
    category4_id,
    brand,
    item_code,
    item_name
FROM {silver_catalog}.categories_clean          
""")
