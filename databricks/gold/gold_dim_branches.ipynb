# %%
# %run ../config

# %%
spark.sql(f"""
CREATE TABLE IF NOT EXISTS {gold_catalog}.dim_branches AS
SELECT
    ROW_NUMBER() OVER (ORDER BY branch_id) AS branch_key,
    branch_id,
    region,
    city,
    town,
    branch_town,
    latitude,
    longitude
FROM {silver_catalog}.branches_clean
""")
